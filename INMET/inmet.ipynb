# %% [markdown]
# ## Acesso aos dados de estações meteorológicas do INMET

# %% [markdown]
# O Instituto Nacional de Meteorologia disponibiliza na página https://portal.inmet.gov.br/dadoshistoricos acesso à dado históricos de estações de coletas de dados. Há dados para algumas estações desde o ano de 2000, e com a passagem dos anos a quantidade de estações disponíveis aumenta (para a cidade de São Paulo, por exemplo, a primeira estação passa a ser disponibilizada na série do ano de 2006)
#
# Na data em que escrevo (20/08/2021) a busca das informações não é muito amigável, não encontrei outra forma de procurar pelos dados senão navegando de arquivo em arquivo. O site disponibiliza outras ferramentas para extração de dados, mas não as verifiquei.
#
# As primeiras oito linhas do arquivo são um cabeçalho de identificação da estação, e os nomes das colunas estão na linha 9. Entre os dois arquivos de exemplo carregados abaixo, as colunas tem os mesmos dados, embora haja alguma diferença na nomenclatura. Seria no entanto interessante fazer uma verificação mais acurada para usar uma série de dados que abranja mais de um ano. Na importação o pandas cria uma coluna `Unnamed: 19` que parece ser apenas porque o arquivo tem um caracter separador extra ao final de cada linha, e pode ser eliminada.
# Também há diferenças no formato de data entre um ano e outro, que podem precisar ser tratadas.
#
# Não busquei informações sobre o tipo de dado de cada coluna, acredito que em caso de necessidade deve-ser verificar em https://portal.inmet.gov.br/.

# %%
import pandas as pd

# %% [markdown]
# ### Dados da cidade de São Paulo
# Para encontrar uma estação é possível verificar um mapa em https://mapas.inmet.gov.br/
# Abaixo estão os dados da estação do Mirante de Santana. na cidade de São Paulo

# %% [markdown]
# <img alt="" src="data:image/png;base64,..." />

# %% [markdown]
# Para exemplificar, estoiu carregando abaixo dois arquivos da série temporal para esta estação, o primeiro disponível (cujas medições começam em 25/07/2006) e o último disponível na data que escrevo (medições terminam em 31/07/2021)

# %%
mirante06 = pd.read_csv('INMET_SE_SP_A701_SAO PAULO - MIRANTE_25-07-2006_A_31-12-2006.CSV', sep=';', header=8, encoding='latin-1')
mirante06
# Out:
#      DATA (YYYY-MM-DD) HORA (UTC) PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0           2006-07-25      00:00                            -9999
# 1           2006-07-25      01:00                            -9999
# 2           2006-07-25      02:00                            -9999
# 3           2006-07-25      03:00                            -9999
# 4           2006-07-25      04:00                            -9999
# ...                ...        ...                              ...
# 3835        2006-12-31      19:00                               12
# 3836        2006-12-31      20:00                                6
# 3837        2006-12-31      21:00                                3
# 3838        2006-12-31      22:00                             11,2
# 3839        2006-12-31      23:00                              1,2
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 -9999
# ...

# %%
mirante21 = pd.read_csv('INMET_SE_SP_A701_SAO PAULO - MIRANTE_01-01-2021_A_31-07-2021.CSV', sep=';', header=8, encoding='latin-1')
mirante21
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2021/01/01  0000 UTC                                0
# 1     2021/01/01  0100 UTC                                0
# 2     2021/01/01  0200 UTC                                0
# 3     2021/01/01  0300 UTC                                0
# 4     2021/01/01  0400 UTC                                0
# ...          ...       ...                              ...
# 5083  2021/07/31  1900 UTC                                0
# 5084  2021/07/31  2000 UTC                                0
# 5085  2021/07/31  2100 UTC                                0
# 5086  2021/07/31  2200 UTC                                0
# 5087  2021/07/31  2300 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 925,4
# 1                                                 925,2
# 2                                                   925
# ...
